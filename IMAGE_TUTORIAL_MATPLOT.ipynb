# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import numpy as np

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-eaed9c5a-2897-40e9-8ac3-c7f27333836c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eaed9c5a-2897-40e9-8ac3-c7f27333836c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving REPTILES.jpg to REPTILES (1).jpg

# %%
img = mpimg.imread('REPTILES.jpg')
print(img)
# Out:
# [[[138 213  84]
#   [138 213  84]
#   [138 213  84]
#   ...
#   [ 99 199  85]
#   [ 98 198  84]
#   [ 97 197  83]]
#
#  [[138 213  84]
#   [138 213  84]
#   [138 213  84]
#   ...
#   [ 99 199  85]
#   [ 98 198  84]
#   [ 97 197  83]]
#
#  [[138 213  84]
#   [138 213  84]
#   [138 213  84]
#   ...
#   [ 99 199  85]
#   [ 98 198  84]
#   [ 97 197  83]]
#
#  ...
#
#  [[ 75 126  67]
#   [ 75 126  67]
#   [ 75 126  67]
#   ...
#   [ 83 196  44]
#   [ 83 196  44]
#   [ 83 196  44]]
#
#  [[ 75 126  67]
#   [ 75 126  67]
#   [ 75 126  67]
#   ...
#   [ 84 197  45]
#   [ 84 197  45]
#   [ 84 197  45]]
#
#  [[ 75 126  67]
#   [ 75 126  67]
#   [ 75 126  67]
#   ...
#   [ 84 197  45]
#   [ 84 197  45]
#   [ 84 197  45]]]

# %%
imgplot = plt.imshow(img)

# %%
lum_img = img[:, :, 0]

# This is array slicing.  You can read more in the `Numpy tutorial


plt.imshow(lum_img)

# %%
plt.imshow(lum_img, cmap="hot")

# %%
imgplot = plt.imshow(lum_img)
plt.colorbar()

# %%
plt.axis("off")
plt.imshow(img)

# %%
grayscale_img = img[:, :, 0]
plt.imshow(grayscale_img, cmap='gray')

# %%
plt.imshow(grayscale_img,cmap ='Oranges_r')

# %%
plt.imshow(grayscale_img,cmap ='bone_r')

# %%
plt.imshow(grayscale_img,cmap ='coolwarm')

# %%
plt.imshow(grayscale_img,cmap ='autumn')

# %%
plt.imshow(grayscale_img,cmap ='icefire')

# %%
plt.imshow(grayscale_img,cmap ='jet_r')

# %%
plt.imshow(grayscale_img,cmap ='YlOrBr')

# %%
plt.imshow(grayscale_img,cmap ='Purples_r')

# %%
plt.imshow(grayscale_img,cmap ='gist_rainbow_r')
